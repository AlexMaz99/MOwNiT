# %% [markdown]
# # Sumowanie liczb pojedynczej precyzji

# %%
from numpy import float32
from matplotlib import pyplot as plt
import time

# %%
def absolute_error(number, approximation):
    return abs(number - approximation)


def relative_error(number, approximation):
    return abs(number - approximation) / number


def iterative_sum(tab):
    sum = float32(0)
    for i in tab:
        sum += i
    return sum

# %%
val = float32(0.53125)
numbers = [val] * 10 ** 7
sum32 = iterative_sum(numbers)
original_sum = val * 10 ** 7

print('Wartość prawidłowa: ', original_sum)
print('Wartość uzyskana po zsumowaniu:', sum32)
print('Błąd bezwzględny:', absolute_error(original_sum, sum32))
print('Błąd względny:', relative_error(original_sum, sum32) * 100, '%')
# Out:
# Wartość prawidłowa:  5312500.0
# Wartość uzyskana po zsumowaniu: 5030840.5
# Błąd bezwzględny: 281659.5
# Błąd względny: 5.301825882352941 %

# %% [markdown]
# Błąd względny jest tak duży, ponieważ dodajemy bardzo małą liczbę do coraz większej sumy.

# %%
def relative_error_plot(numbers):
    sum = float32(0)
    sum2 = 0
    x = 0
    tab = []
    for i in numbers:
        sum += i
        sum2 += i
        if x % 25000 == 0:
            tab.append(relative_error(sum2, sum) * 100)
        x += 1
    plt.plot(tab)
    plt.show()
relative_error_plot(numbers)

# %%
def recursive_sum(xs):
    length = len(xs)
    if length == 0:
        return 0
    if length == 1:
        return xs[0]
    else:
        return recursive_sum(xs[:length//2]) + recursive_sum(xs[length//2:])
sum3 = recursive_sum(numbers)

# %%
print('Wartość prawidłowa: ', original_sum)
print('Suma obliczona rekurencyjnie: ', sum3)
print('Błąd bezwzględny: ', absolute_error(original_sum, sum3))
print('Błąd względny: ', relative_error(original_sum, sum3) * 100, '%')
# Out:
# Wartość prawidłowa:  5312500.0
# Suma obliczona rekurencyjnie:  5312500.0
# Błąd bezwzględny:  0.0
# Błąd względny:  0.0 %

# %% [markdown]
# Błąd względny jest równy 0 %, ponieważ rekurencyjnie dodajemy do siebie bardzo podobne liczby. Bity mantysy nie są tracone.

# %% [markdown]
# Jednak jeżeli w tablicy będą obok siebie liczby bardzo duże i bardzo małe to błąd wzrośnie.

# %%
def not_zero_error():
    x = float32(0.0001)
    y = float32(10000)
    numbers2 = []
    sum64 = float(0)
    for i in range(10 ** 7 + 1):
        if i % 2 == 0:
            numbers2.append(x)
            sum64 += x
        else:
            numbers2.append(y)
            sum64 += y
    sum4 = recursive_sum(numbers2)
    print('Suma obliczona rekurencyjnie: ', sum4)
    print('Wartość prawidłowa: ', sum64)
    print('Błąd bezwzględny: ', absolute_error(sum64, sum4))
    print('Błąd względny: ', relative_error(sum64, sum4) * 100, '%')
not_zero_error()
# Out:
# Suma obliczona rekurencyjnie:  50000003000.0
# Wartość prawidłowa:  50000000496.69094
# Błąd bezwzględny:  2575.3090591430664
# Błąd względny:  5.150618067120826e-06 %

# %% [markdown]
# # Algorytm Kahana

# %%
def Kahan_sum (tab, function):
    sum = function(0.0)
    err = function(0.0)
    for i in tab:
        y = function(i - err)
        tmp = function(sum + y)
        err = function((tmp - sum) - y)
        sum = tmp
    return sum
# (tmp - sum) odzyskuje wyższe bity y 
# odjęcie y odzyskuje niższe bity y
kahan_sum = Kahan_sum(numbers, float32)
original_sum = val * 10 ** 7

# %%
print("Suma prawidłowa: ", original_sum)
print("Suma obliczona algorytmem Kahana: ", kahan_sum)
print('Błąd bezwzględny: ', absolute_error(original_sum, kahan_sum))
print('Błąd względny: ', relative_error(original_sum, kahan_sum) * 100, '%')
# Out:
# Suma prawidłowa:  5312500.0
# Suma obliczona algorytmem Kahana:  5312500.0
# Błąd bezwzględny:  0.0
# Błąd względny:  0.0 %

# %% [markdown]
# Algorytm Kahana w każdej iteracji pętli przechowuje w zmiennej err bity, które zostały utracone przez dodawanie małych i dużych liczb. W kolejnej iteracji są one uwzględniane, dzięki czemu błąd zdecydowanie zmalał.

# %%
def compare_time():
    start = time.time() * 1000
    iterative_sum(numbers)
    end = time.time() * 1000
    time_sum1 = (end - start).__round__(2)
    print(f"Czas dla sumy obliczonej iteracyjnie: {time_sum1} milisekund")
    start = time.time() * 1000
    Kahan_sum(numbers, float32)
    end = time.time() * 1000
    time_sum1 = (end - start).__round__(2)
    print(f"Czas dla sumy obliczonej algorytmem Kahana: {time_sum1} milisekund")
    start = time.time() * 1000
    recursive_sum(numbers)
    end = time.time() * 1000
    time_recursive_sum = (end - start).__round__(2)
    print(f"Czas dla sumy obliczonej rekurencyjnie: {time_recursive_sum} milisekund")
compare_time()
# Out:
# Czas dla sumy obliczonej iteracyjnie: 1253.96 milisekund
# Czas dla sumy obliczonej algorytmem Kahana: 20165.82 milisekund
# Czas dla sumy obliczonej rekurencyjnie: 10895.82 milisekund

# %% [markdown]
# # Sumy częściowe

# %%
tab_s = [float32(2), float32(3.6667), float32(5), float32(7.2), float32(10)]
tab_n = [50, 100, 200, 500, 1000]


def zeta_riemann_forward(s, n, function):
    sum = function(0)
    for k in range(1, n + 1, 1):
        sum += function(1 / (k ** s))
    return sum


def zeta_riemann_backward(s, n, function):
    backward_sum = function(0)
    for k in range(n, 0, -1):
        backward_sum += function(1 / (k ** s))
    return backward_sum


def eta_dirichlet_forward(s, n, function):
    sum = function(0)
    for k in range(1, n + 1, 1):
        sum += function((-1) ** (k - 1) * 1 / (k ** s))
    return sum


def eta_dirichlet_backward(s, n, function):
    backward_sum = function(0)
    for k in range(n, 0, -1):
        backward_sum += function((-1) ** (k - 1) * 1 / (k ** s))
    return backward_sum

# %%
def compare_precision(tab_n, tab_s):
    for s in tab_s:
        for n in tab_n:
            riemann_sum32_f = zeta_riemann_forward(s, n, float32)
            riemann_sum32_b = zeta_riemann_backward(s, n, float32)
            riemann_sum64_f = zeta_riemann_forward(s, n, float)
            riemann_sum64_b = zeta_riemann_backward(s, n, float)
            dirichlet_sum32_f = eta_dirichlet_forward(s, n, float32)
            dirichlet_sum32_b = eta_dirichlet_backward(s, n, float32)
            dirichlet_sum64_f = eta_dirichlet_forward(s, n, float)
            dirichlet_sum64_b = eta_dirichlet_backward(s, n, float)

            print("s: ", s, "n: ", n)
            print("Riemann dla float32")
            print("Suma obliczona w przód: ", riemann_sum32_f)
            print("Suma obliczona wstecz: ", riemann_sum32_b)
            print("Różnica między powyższymi: ", abs(riemann_sum32_b - riemann_sum32_f))
            print("\n")
            print("Riemann dla float64")
            print("Suma obliczona w przód: ", riemann_sum64_f)
            print("Suma obliczona wstecz: ", riemann_sum64_b)
            print("Różnica między powyższymi: ", abs(riemann_sum64_b - riemann_sum64_f))
            print("\n")
            print("Riemann")
            print("Różnica między float32 i float64 w przód: ", abs(riemann_sum64_f - riemann_sum32_f))
            print("Różnica między float32 i float64 wstecz: ", abs(riemann_sum64_b - riemann_sum32_b))
            print("\n")
            print("Dirichlet dla float32")
            print("Suma obliczona w przód: ", dirichlet_sum32_f)
            print("Suma obliczona wstecz: ", dirichlet_sum32_b)
            print("Różnica między powyższymi: ", abs(dirichlet_sum32_b - dirichlet_sum32_f))
            print("\n")
            print("Dirichlet dla float64")
            print("Suma obliczona w przód: ", dirichlet_sum64_f)
            print("Suma obliczona wstecz: ", dirichlet_sum64_b)
            print("Różnica między powyższymi: ", abs(dirichlet_sum64_b - dirichlet_sum64_f))
            print("\n")
            print("Dirichlet")
            print("Różnica między float32 i float64 w przód: ", abs(dirichlet_sum64_f - dirichlet_sum32_f))
            print("Różnica między float32 i float64 wstecz: ", abs(dirichlet_sum64_b - dirichlet_sum32_b))
            print("\n")
            print("-----------------------------------------")
compare_precision(tab_n, tab_s)
# Out:
# s:  2.0 n:  50
# Riemann dla float32
# Suma obliczona w przód:  1.6251329
# Suma obliczona wstecz:  1.6251327
# Różnica między powyższymi:  2.3841858e-07
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.625132733621529
# Suma obliczona wstecz:  1.6251327336215293
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Riemann
# Różnica między float32 i float64 w przód:  1.8473632001914098e-07
# Różnica między float32 i float64 wstecz:  5.368225930446613e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.822271
# Suma obliczona wstecz:  0.82227105
# Różnica między powyższymi:  5.9604645e-08
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.8222710318260295
# Suma obliczona wstecz:  0.8222710318260289
# Różnica między powyższymi:  5.551115123125783e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  4.240799966748199e-08
# Różnica między float32 i float64 wstecz:  1.719664566302015e-08
#
#
# -----------------------------------------
# s:  2.0 n:  100
# Riemann dla float32
# Suma obliczona w przód:  1.634984
# Suma obliczona wstecz:  1.6349839
# Różnica między powyższymi:  1.1920929e-07
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.6349839001848923
# Suma obliczona wstecz:  1.634983900184893
# Różnica między powyższymi:  6.661338147750939e-16
#
#
# Riemann
# Różnica między float32 i float64 w przód:  1.1623356477308278e-07
# Różnica między float32 i float64 wstecz:  2.975725443832289e-09
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.8224175
# Suma obliczona wstecz:  0.8224175
# Różnica między powyższymi:  0.0
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.8224175333741286
# Suma obliczona wstecz:  0.8224175333741282
# Różnica między powyższymi:  4.440892098500626e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  3.573924090005676e-08
# Różnica między float32 i float64 wstecz:  3.573924045596755e-08
#
#
# -----------------------------------------
# s:  2.0 n:  200
# Riemann dla float32
# Suma obliczona w przód:  1.6399467
# Suma obliczona wstecz:  1.6399465
# Różnica między powyższymi:  2.3841858e-07
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.6399465460149971
# Suma obliczona wstecz:  1.6399465460149973
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Riemann
# Różnica między float32 i float64 w przód:  1.5312745893503177e-07
# Różnica między float32 i float64 wstecz:  8.529112038857534e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.8224547
# Suma obliczona wstecz:  0.8224546
# Różnica między powyższymi:  1.1920929e-07
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.822454595922551
# Suma obliczona wstecz:  0.8224545959225509
# Różnica między powyższymi:  1.1102230246251565e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  9.501067654849038e-08
# Różnica między float32 i float64 wstecz:  2.4198612891268567e-08
#
#
# -----------------------------------------
# s:  2.0 n:  500
# Riemann dla float32
# Suma obliczona w przód:  1.642936
# Suma obliczona wstecz:  1.642936
# Różnica między powyższymi:  0.0
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.642936065514894
# Suma obliczona wstecz:  1.6429360655148941
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Riemann
# Różnica między float32 i float64 w przód:  7.422766246101276e-08
# Różnica między float32 i float64 wstecz:  7.422766268305736e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.82246536
# Suma obliczona wstecz:  0.82246506
# Różnica między powyższymi:  2.9802322e-07
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.8224650374240963
# Suma obliczona wstecz:  0.8224650374240972
# Różnica między powyższymi:  8.881784197001252e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  3.2274054606595826e-07
# Różnica między float32 i float64 wstecz:  2.471732130082671e-08
#
#
# -----------------------------------------
# s:  2.0 n:  1000
# Riemann dla float32
# Suma obliczona w przód:  1.6439348
# Suma obliczona wstecz:  1.6439345
# Różnica między powyższymi:  3.5762787e-07
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.6439345666815615
# Suma obliczona wstecz:  1.6439345666815597
# Różnica między powyższymi:  1.7763568394002505e-15
#
#
# Riemann
# Różnica między float32 i float64 w przód:  2.7924281598146194e-07
# Różnica między float32 i float64 wstecz:  7.838505089452497e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.82246685
# Suma obliczona wstecz:  0.82246655
# Różnica między powyższymi:  2.9802322e-07
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.8224665339241114
# Suma obliczona wstecz:  0.8224665339241127
# Różnica między powyższymi:  1.3322676295501878e-15
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  3.163566503205928e-07
# Różnica między float32 i float64 wstecz:  1.8333425111372037e-08
#
#
# -----------------------------------------
# s:  3.6667 n:  50
# Riemann dla float32
# Suma obliczona w przód:  1.1093994
# Suma obliczona wstecz:  1.1093998
# Różnica między powyższymi:  3.5762787e-07
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.1093997659868537
# Suma obliczona wstecz:  1.1093997659868533
# Różnica między powyższymi:  4.440892098500626e-16
#
#
# Riemann
# Różnica między float32 i float64 w przód:  3.280824958373785e-07
# Różnica między float32 i float64 wstecz:  2.9545373259054486e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.9346931
# Suma obliczona wstecz:  0.93469304
# Różnica między powyższymi:  5.9604645e-08
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9346930553947345
# Suma obliczona wstecz:  0.9346930553947342
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  4.2673502842482947e-08
# Różnica między float32 i float64 wstecz:  1.6931141710863074e-08
#
#
# -----------------------------------------
# s:  3.6667 n:  100
# Riemann dla float32
# Suma obliczona w przód:  1.1094086
# Suma obliczona wstecz:  1.1094089
# Różnica między powyższymi:  2.3841858e-07
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.10940880817909
# Suma obliczona wstecz:  1.1094088081790894
# Różnica między powyższymi:  6.661338147750939e-16
#
#
# Riemann
# Różnica między float32 i float64 w przód:  1.9115943672431968e-07
# Różnica między float32 i float64 wstecz:  4.725914304337664e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.9346933
# Suma obliczona wstecz:  0.93469334
# Różnica między powyższymi:  5.9604645e-08
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9346933165042048
# Suma obliczona wstecz:  0.934693316504205
# Różnica między powyższymi:  1.1102230246251565e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  3.9622033209951724e-08
# Różnica między float32 i float64 wstecz:  1.99826114544166e-08
#
#
# -----------------------------------------
# s:  3.6667 n:  200
# Riemann dla float32
# Suma obliczona w przód:  1.1094086
# Suma obliczona wstecz:  1.1094103
# Różnica między powyższymi:  1.66893e-06
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.1094102531709698
# Suma obliczona wstecz:  1.1094102531709702
# Różnica między powyższymi:  4.440892098500626e-16
#
#
# Riemann
# Różnica między float32 i float64 w przód:  1.6361513164309116e-06
# Różnica między float32 i float64 wstecz:  3.2778736835936684e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.9346933
# Suma obliczona wstecz:  0.93469334
# Różnica między powyższymi:  5.9604645e-08
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9346933374728346
# Suma obliczona wstecz:  0.9346933374728339
# Różnica między powyższymi:  6.661338147750939e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  6.059066293140347e-08
# Różnica między float32 i float64 wstecz:  9.86017489879032e-10
#
#
# -----------------------------------------
# s:  3.6667 n:  500
# Riemann dla float32
# Suma obliczona w przód:  1.1094086
# Suma obliczona wstecz:  1.1094105
# Różnica między powyższymi:  1.9073486e-06
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.1094105016819698
# Suma obliczona wstecz:  1.1094105016819695
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Riemann
# Różnica między float32 i float64 w przód:  1.8846623164314735e-06
# Różnica między float32 i float64 wstecz:  2.2686316603071077e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.9346933
# Suma obliczona wstecz:  0.93469334
# Różnica między powyższymi:  5.9604645e-08
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9346933392200255
# Suma obliczona wstecz:  0.9346933392200247
# Różnica między powyższymi:  7.771561172376096e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  6.233785387887991e-08
# Różnica między float32 i float64 wstecz:  2.7332083263331697e-09
#
#
# -----------------------------------------
# s:  3.6667 n:  1000
# Riemann dla float32
# Suma obliczona w przód:  1.1094086
# Suma obliczona wstecz:  1.1094105
# Różnica między powyższymi:  1.9073486e-06
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.109410521680274
# Suma obliczona wstecz:  1.1094105216802712
# Różnica między powyższymi:  2.886579864025407e-15
#
#
# Riemann
# Różnica między float32 i float64 w przód:  1.904660620777321e-06
# Różnica między float32 i float64 wstecz:  2.6880149217589633e-09
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.9346933
# Suma obliczona wstecz:  0.93469334
# Różnica między powyższymi:  5.9604645e-08
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9346933392782865
# Suma obliczona wstecz:  0.9346933392782852
# Różnica między powyższymi:  1.2212453270876722e-15
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  6.239611483049856e-08
# Różnica między float32 i float64 wstecz:  2.7914688338626092e-09
#
#
# -----------------------------------------
# s:  5.0 n:  50
# Riemann dla float32
# Suma obliczona w przód:  1.0369275
# Suma obliczona wstecz:  1.0369277
# Różnica między powyższymi:  2.3841858e-07
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.036927716716712
# Suma obliczona wstecz:  1.0369277167167108
# Różnica między powyższymi:  1.1102230246251565e-15
#
#
# Riemann
# Różnica między float32 i float64 w przód:  2.550925664035475e-07
# Różnica między float32 i float64 wstecz:  1.667398619176197e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.9721198
# Suma obliczona wstecz:  0.97211975
# Różnica między powyższymi:  5.9604645e-08
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9721197689267979
# Suma obliczona wstecz:  0.9721197689267976
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  3.927022362848476e-08
# Różnica między float32 i float64 wstecz:  2.0334420924861263e-08
#
#
# -----------------------------------------
# s:  5.0 n:  100
# Riemann dla float32
# Suma obliczona w przód:  1.0369275
# Suma obliczona wstecz:  1.0369277
# Różnica między powyższymi:  2.3841858e-07
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.0369277526929555
# Suma obliczona wstecz:  1.0369277526929532
# Różnica między powyższymi:  2.220446049250313e-15
#
#
# Riemann
# Różnica między float32 i float64 w przód:  2.9106880994334006e-07
# Różnica między float32 i float64 wstecz:  5.265022862133151e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.9721198
# Suma obliczona wstecz:  0.97211975
# Różnica między powyższymi:  5.9604645e-08
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9721197703981592
# Suma obliczona wstecz:  0.9721197703981589
# Różnica między powyższymi:  3.3306690738754696e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  3.779886226240592e-08
# Różnica między float32 i float64 wstecz:  2.18057821799178e-08
#
#
# -----------------------------------------
# s:  5.0 n:  200
# Riemann dla float32
# Suma obliczona w przód:  1.0369275
# Suma obliczona wstecz:  1.0369277
# Różnica między powyższymi:  2.3841858e-07
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.0369277549886775
# Suma obliczona wstecz:  1.036927754988676
# Różnica między powyższymi:  1.5543122344752192e-15
#
#
# Riemann
# Różnica między float32 i float64 w przód:  2.933645320002398e-07
# Różnica między float32 i float64 wstecz:  5.4945951344365085e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.9721198
# Suma obliczona wstecz:  0.97211975
# Różnica między powyższymi:  5.9604645e-08
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.972119770445367
# Suma obliczona wstecz:  0.9721197704453663
# Różnica między powyższymi:  6.661338147750939e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  3.775165446917583e-08
# Różnica między float32 i float64 wstecz:  2.1852989640080978e-08
#
#
# -----------------------------------------
# s:  5.0 n:  500
# Riemann dla float32
# Suma obliczona w przód:  1.0369275
# Suma obliczona wstecz:  1.0369277
# Różnica między powyższymi:  2.3841858e-07
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.0369277551393863
# Suma obliczona wstecz:  1.0369277551393858
# Różnica między powyższymi:  4.440892098500626e-16
#
#
# Riemann
# Różnica między float32 i float64 w przód:  2.935152407790298e-07
# Różnica między float32 i float64 wstecz:  5.5096661233378086e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.9721198
# Suma obliczona wstecz:  0.97211975
# Różnica między powyższymi:  5.9604645e-08
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9721197704468947
# Suma obliczona wstecz:  0.9721197704468933
# Różnica między powyższymi:  1.3322676295501878e-15
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  3.775012680229395e-08
# Różnica między float32 i float64 wstecz:  2.1854516640829047e-08
#
#
# -----------------------------------------
# s:  5.0 n:  1000
# Riemann dla float32
# Suma obliczona w przód:  1.0369275
# Suma obliczona wstecz:  1.0369277
# Różnica między powyższymi:  2.3841858e-07
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.0369277551431222
# Suma obliczona wstecz:  1.0369277551431204
# Różnica między powyższymi:  1.7763568394002505e-15
#
#
# Riemann
# Różnica między float32 i float64 w przód:  2.9351897667950766e-07
# Różnica między float32 i float64 wstecz:  5.510039580158832e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.9721198
# Suma obliczona wstecz:  0.97211975
# Różnica między powyższymi:  5.9604645e-08
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9721197704469091
# Suma obliczona wstecz:  0.9721197704469088
# Różnica między powyższymi:  3.3306690738754696e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  3.775011236939463e-08
# Różnica między float32 i float64 wstecz:  2.185453207292909e-08
#
#
# -----------------------------------------
# s:  7.2 n:  50
# Riemann dla float32
# Suma obliczona w przód:  1.0072277
# Suma obliczona wstecz:  1.0072277
# Różnica między powyższymi:  0.0
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.0072276674688423
# Suma obliczona wstecz:  1.0072276674688425
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Riemann
# Różnica między float32 i float64 w przód:  8.243378424310777e-09
# Różnica między float32 i float64 wstecz:  8.243378646355382e-09
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.99352705
# Suma obliczona wstecz:  0.993527
# Różnica między powyższymi:  5.9604645e-08
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9935269998290788
# Suma obliczona wstecz:  0.9935269998290788
# Różnica między powyższymi:  0.0
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  5.495760335705313e-08
# Różnica między float32 i float64 wstecz:  4.647041418337494e-09
#
#
# -----------------------------------------
# s:  7.2 n:  100
# Riemann dla float32
# Suma obliczona w przód:  1.0072277
# Suma obliczona wstecz:  1.0072277
# Różnica między powyższymi:  0.0
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.0072276674732148
# Suma obliczona wstecz:  1.0072276674732152
# Różnica między powyższymi:  4.440892098500626e-16
#
#
# Riemann
# Różnica między float32 i float64 w przód:  8.24775092667096e-09
# Różnica między float32 i float64 wstecz:  8.24775137076017e-09
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.99352705
# Suma obliczona wstecz:  0.993527
# Różnica między powyższymi:  5.9604645e-08
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9935269998293487
# Suma obliczona wstecz:  0.9935269998293484
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  5.4957333461835844e-08
# Różnica między float32 i float64 wstecz:  4.647311091510176e-09
#
#
# -----------------------------------------
# s:  7.2 n:  200
# Riemann dla float32
# Suma obliczona w przód:  1.0072277
# Suma obliczona wstecz:  1.0072277
# Różnica między powyższymi:  0.0
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.0072276674732752
# Suma obliczona wstecz:  1.0072276674732767
# Różnica między powyższymi:  1.5543122344752192e-15
#
#
# Riemann
# Różnica między float32 i float64 w przód:  8.2478113228035e-09
# Różnica między float32 i float64 wstecz:  8.247812877115734e-09
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.99352705
# Suma obliczona wstecz:  0.993527
# Różnica między powyższymi:  5.9604645e-08
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9935269998293503
# Suma obliczona wstecz:  0.9935269998293504
# Różnica między powyższymi:  1.1102230246251565e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  5.495733179650131e-08
# Różnica między float32 i float64 wstecz:  4.64731308991162e-09
#
#
# -----------------------------------------
# s:  7.2 n:  500
# Riemann dla float32
# Suma obliczona w przód:  1.0072277
# Suma obliczona wstecz:  1.0072277
# Różnica między powyższymi:  0.0
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.0072276674732752
# Suma obliczona wstecz:  1.0072276674732774
# Różnica między powyższymi:  2.220446049250313e-15
#
#
# Riemann
# Różnica między float32 i float64 w przód:  8.2478113228035e-09
# Różnica między float32 i float64 wstecz:  8.24781354324955e-09
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.99352705
# Suma obliczona wstecz:  0.993527
# Różnica między powyższymi:  5.9604645e-08
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9935269998293503
# Suma obliczona wstecz:  0.9935269998293504
# Różnica między powyższymi:  1.1102230246251565e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  5.495733179650131e-08
# Różnica między float32 i float64 wstecz:  4.64731308991162e-09
#
#
# -----------------------------------------
# s:  7.2 n:  1000
# Riemann dla float32
# Suma obliczona w przód:  1.0072277
# Suma obliczona wstecz:  1.0072277
# Różnica między powyższymi:  0.0
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.0072276674732752
# Suma obliczona wstecz:  1.0072276674732774
# Różnica między powyższymi:  2.220446049250313e-15
#
#
# Riemann
# Różnica między float32 i float64 w przód:  8.2478113228035e-09
# Różnica między float32 i float64 wstecz:  8.24781354324955e-09
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.99352705
# Suma obliczona wstecz:  0.993527
# Różnica między powyższymi:  5.9604645e-08
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9935269998293503
# Suma obliczona wstecz:  0.9935269998293504
# Różnica między powyższymi:  1.1102230246251565e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  5.495733179650131e-08
# Różnica między float32 i float64 wstecz:  4.64731308991162e-09
#
#
# -----------------------------------------
# s:  10.0 n:  50
# Riemann dla float32
# Suma obliczona w przód:  1.0009946
# Suma obliczona wstecz:  1.0009946
# Różnica między powyższymi:  0.0
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.0009945751278182
# Suma obliczona wstecz:  1.000994575127818
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Riemann
# Różnica między float32 i float64 w przód:  1.202509603004387e-08
# Różnica między float32 i float64 wstecz:  1.2025095807999264e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.99903953
# Suma obliczona wstecz:  0.99903953
# Różnica między powyższymi:  0.0
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9990395075982718
# Suma obliczona wstecz:  0.9990395075982715
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  2.3155817596709483e-08
# Różnica między float32 i float64 wstecz:  2.3155817818754088e-08
#
#
# -----------------------------------------
# s:  10.0 n:  100
# Riemann dla float32
# Suma obliczona w przód:  1.0009946
# Suma obliczona wstecz:  1.0009946
# Różnica między powyższymi:  0.0
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.0009945751278182
# Suma obliczona wstecz:  1.000994575127818
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Riemann
# Różnica między float32 i float64 w przód:  1.202509603004387e-08
# Różnica między float32 i float64 wstecz:  1.2025095807999264e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.99903953
# Suma obliczona wstecz:  0.99903953
# Różnica między powyższymi:  0.0
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9990395075982718
# Suma obliczona wstecz:  0.9990395075982715
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  2.3155817596709483e-08
# Różnica między float32 i float64 wstecz:  2.3155817818754088e-08
#
#
# -----------------------------------------
# s:  10.0 n:  200
# Riemann dla float32
# Suma obliczona w przód:  1.0009946
# Suma obliczona wstecz:  1.0009946
# Różnica między powyższymi:  0.0
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.0009945751278182
# Suma obliczona wstecz:  1.000994575127818
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Riemann
# Różnica między float32 i float64 w przód:  1.202509603004387e-08
# Różnica między float32 i float64 wstecz:  1.2025095807999264e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.99903953
# Suma obliczona wstecz:  0.99903953
# Różnica między powyższymi:  0.0
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9990395075982718
# Suma obliczona wstecz:  0.9990395075982715
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  2.3155817596709483e-08
# Różnica między float32 i float64 wstecz:  2.3155817818754088e-08
#
#
# -----------------------------------------
# s:  10.0 n:  500
# Riemann dla float32
# Suma obliczona w przód:  1.0009946
# Suma obliczona wstecz:  1.0009946
# Różnica między powyższymi:  0.0
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.0009945751278182
# Suma obliczona wstecz:  1.000994575127818
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Riemann
# Różnica między float32 i float64 w przód:  1.202509603004387e-08
# Różnica między float32 i float64 wstecz:  1.2025095807999264e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.99903953
# Suma obliczona wstecz:  0.99903953
# Różnica między powyższymi:  0.0
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9990395075982718
# Suma obliczona wstecz:  0.9990395075982715
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  2.3155817596709483e-08
# Różnica między float32 i float64 wstecz:  2.3155817818754088e-08
#
#
# -----------------------------------------
# s:  10.0 n:  1000
# Riemann dla float32
# Suma obliczona w przód:  1.0009946
# Suma obliczona wstecz:  1.0009946
# Różnica między powyższymi:  0.0
#
#
# Riemann dla float64
# Suma obliczona w przód:  1.0009945751278182
# Suma obliczona wstecz:  1.000994575127818
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Riemann
# Różnica między float32 i float64 w przód:  1.202509603004387e-08
# Różnica między float32 i float64 wstecz:  1.2025095807999264e-08
#
#
# Dirichlet dla float32
# Suma obliczona w przód:  0.99903953
# Suma obliczona wstecz:  0.99903953
# Różnica między powyższymi:  0.0
#
#
# Dirichlet dla float64
# Suma obliczona w przód:  0.9990395075982718
# Suma obliczona wstecz:  0.9990395075982715
# Różnica między powyższymi:  2.220446049250313e-16
#
#
# Dirichlet
# Różnica między float32 i float64 w przód:  2.3155817596709483e-08
# Różnica między float32 i float64 wstecz:  2.3155817818754088e-08
#
#
# -----------------------------------------

# %% [markdown]
# Obliczone sumy częściowe funkcji dzeta Riemanna i eta Dirichleta różnią się w zależności od kolejności sumowania wyrazów. Podczas sumowania od przodu błąd jest większy ponieważ wartość sumy rośnie, a dodawany element maleje. Sumowanie od tyłu zachowuje większą dokładność, ponieważ wartość sumy rośnie wraz z dodawanymi elementami.

# %% [markdown]
# #  Błędy zaokrągleń i odwzorowanie logistyczne

# %%
from numpy import arange

N = 1000

def x_N(x_0, r, function):
    tab = [function(x_0)]
    r = function(r)
    for i in range(0, N):
        tab.append(function(r * tab[i] * (1 - tab[i])))
    return tab

# %%
def a(how_many):

    for x_0 in arange(0.1, 1, 0.2):
        for r in arange(1, 4, 0.01):
            tab = x_N(x_0, r, float32)
            for i in (N - how_many, N):
                plt.plot(r, tab[i], '.', markersize=2)
        plt.title(x_0)
        plt.show()

# %%
a(1)

# %% [markdown]
# Powyższe wykresy przedstawiają zachowanie ciągu rekurencyjnego po wielu iteracjach dla różnych wartości x0 (oś pionowa). Na osi poziomej zaznaczone są wartości parametru r. Zbieżność rozważanego odwzorowania logistycznego jest silnie zależna od przyjętej wartości r, a od wartości $x_0$ zależy w bardzo małym stopniu.

# %%
def b():
    R = []
    for r in arange(3.75, 3.8, 0.0001):
        R.append(r)
    for x_0 in [0.4, 0.8]:
        xN32 = []
        xN64 = []
        for r in R:
            xN32.append(x_N(x_0, r, float32)[N - 1])
            xN64.append(x_N(x_0, r, float)[N - 1])
        plt.subplot(1, 2, 1)
        plt.plot(R, xN32, '.', markersize=2)
        plt.subplot(1, 2, 2)
        plt.plot(R, xN64, '.', markersize=2)
        plt.show()
b()

# %% [markdown]
# Powyższe wykresy przedstawiają diagram bifurkacyjny dla $r \in [3.75, 3.8]$ dla liczb pojedynczej i podwójnej precyzji. Jaki widać wykresy różnią się od siebie w zależności od użytej precyzji.

# %%
def c():
    r = float32(4)
    eps = 1e-5

    iterations = []
    for x_0 in arange(0.01, 1, 0.001):
        tab = [float32(x_0)]
        i = 0
        while tab[i] > eps and i < 3500:
            tab.append(r * tab[i] * (1 - tab[i]))
            i = i + 1
        iterations.append(i)
    plt.plot(arange(0.01, 1, 0.001), iterations, '.', markersize=2)
    plt.show()
c()

# %% [markdown]
# Jak widać na powyższym wykresie liczba 0 jest przeważnie osiągana stosunkowo szybko. Większość wyników jest mniejsza niż 1500 operacji.
